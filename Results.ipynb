# %%
import pandas as pd

# %%
df = pd.read_csv("result/Ridge.csv")
df
# Out:
#    Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0           0       0.652214      0.020995         0.029574        0.003468
# 1           1       0.595645      0.062688         0.025659        0.001189
# 2           2       0.575381      0.038133         0.024686        0.001730
# 3           3       0.578961      0.018919         0.024993        0.001552
# 4           4       0.553888      0.048630         0.021308        0.008039
#
#    param_model__alpha                    params  split0_test_score  \
# 0                 0.1     {'model__alpha': 0.1}           0.780254
# 1                 1.0     {'model__alpha': 1.0}           0.780223
# 2                10.0    {'model__alpha': 10.0}           0.785315
# 3               100.0   {'model__alpha': 100.0}           0.786389
# 4              1000.0  {'model__alpha': 1000.0}           0.766342
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# ...

# %%
df = pd.read_csv("result/Ridge.csv")
df[["param_model__alpha", "mean_test_score", "rank_test_score"]]
# Out:
#    param_model__alpha  mean_test_score  rank_test_score
# 0                 0.1         0.768234                4
# 1                 1.0         0.769869                3
# 2                10.0         0.775551                2
# 3               100.0         0.777309                1
# 4              1000.0         0.752188                5

# %%
df = pd.read_csv("result/ElasticNet.csv")
df
# Out:
#    Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0           0      35.716229      2.462536         0.028339        0.003555
# 1           1      39.755957      4.929681         0.034823        0.004319
# 2           2      23.930580      3.253267         0.036122        0.004659
# 3           3      24.365487      2.581859         0.030674        0.010755
# 4           4       2.365579      0.203261         0.032324        0.004178
# 5           5       1.301325      0.048831         0.035071        0.003406
# 6           6       1.099869      0.071947         0.033259        0.005486
# 7           7       0.666797      0.015189         0.032061        0.002425
# 8           8       0.614359      0.041245         0.028622        0.003744
#
#    param_model__alpha  param_model__l1_ratio  \
# 0               0.001                    0.1
# 1               0.001                    0.5
# 2               0.001                    0.9
# ...

# %%
df = pd.read_csv("result/LinearSVR.csv")
df
# Out:
#    Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0           0      90.259837      1.320352         0.057826        0.021372
# 1           1       9.569485      0.284682         0.016162        0.000988
# 2           2     159.295112      6.707989         0.019537        0.003786
# 3           3      91.483284      5.116170         0.016444        0.001434
# 4           4     182.356764      8.644955         0.020906        0.003263
# 5           5     175.827229     11.167339         0.016459        0.001458
# 6           6     161.023362      1.752178         0.015880        0.001246
# 7           7     158.728495      0.860527         0.016440        0.001372
# 8           8     160.284822      1.114932         0.016532        0.001588
# 9           9     145.407548     13.928060         0.013573        0.002072
#
#    param_model__C            param_model__loss  \
# 0            0.01          epsilon_insensitive
# ...

# %%
df[df.param_model__loss == "squared_epsilon_insensitive"]
# Out:
#    Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 1           1       9.569485      0.284682         0.016162        0.000988
# 3           3      91.483284      5.116170         0.016444        0.001434
# 5           5     175.827229     11.167339         0.016459        0.001458
# 7           7     158.728495      0.860527         0.016440        0.001372
# 9           9     145.407548     13.928060         0.013573        0.002072
#
#    param_model__C            param_model__loss  \
# 1            0.01  squared_epsilon_insensitive
# 3            0.10  squared_epsilon_insensitive
# 5            1.00  squared_epsilon_insensitive
# 7           10.00  squared_epsilon_insensitive
# 9          100.00  squared_epsilon_insensitive
#
#                                               params  split0_test_score  \
# 1  {'model__C': 0.01, 'model__loss': 'squared_eps...           0.787689
# 3  {'model__C': 0.1, 'model__loss': 'squared_epsi...           0.783267
# ...

# %%
df = pd.read_csv("result/GradientBoostingRegressor.csv")
df
# Out:
#    Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0           0      52.027580      0.748877         0.027726        0.001582
# 1           1     103.970696      0.725330         0.032390        0.000410
# 2           2     158.188339      0.820744         0.036558        0.000372
# 3           3      73.431068      0.708227         0.030543        0.000637
# 4           4     154.791722      0.910157         0.036936        0.000568
# 5           5     236.340085      0.361171         0.042633        0.001349
# 6           6      93.786086      0.767140         0.032558        0.000955
# 7           7     202.546509      0.697256         0.041576        0.000632
# 8           8     295.853334     19.945219         0.041941        0.006580
#
#    param_model__max_depth  param_model__n_estimators  \
# 0                       4                         50
# 1                       4                        100
# ...

# %%
df = pd.read_csv("result/RandomForestRegressor.csv")
df
# Out:
#     Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0            0      34.153160      0.252268         0.027616        0.002270
# 1            1      67.942859      0.287103         0.033145        0.002024
# 2            2     102.135229      0.402760         0.036365        0.001387
# 3            3      50.157058      0.336967         0.026386        0.001088
# 4            4     100.250093      0.489691         0.034009        0.000638
# 5            5     149.471696      0.587328         0.042181        0.000372
# 6            6      64.125926      0.237221         0.028869        0.000455
# 7            7     128.197812      0.306128         0.041595        0.000748
# 8            8     192.188969      0.411613         0.052409        0.002175
# 9            9     157.689254      2.339161         0.085481        0.002341
# 10          10     318.126973      2.863893         0.155607        0.002863
# ...

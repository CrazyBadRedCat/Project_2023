# %%
import pickle
import pandas as pd
import numpy as np

meta = pd.read_csv('kernels_meta.csv')
    
with open('enc_states_sync_all.p', 'rb') as fp:
    all_comps = pickle.load(fp)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import mean_absolute_error as MAE
from sklearn.metrics import r2_score, make_scorer
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

r2_scorer = make_scorer(r2_score)

train_data, test_data = train_test_split(
    all_comps,
    test_size = 0.25,
    random_state = 14
)

def transform_target(target):
    ans = np.zeros(78)
    coef = 1.0
    gamma = 0.5
    
    for snip in target:
        ans[snip] += coef
        coef *= gamma
        if coef < 0.0001:
            break

    return ans

def sigmoid(x):
    return x / (1.0 + np.abs(x))

def generate_data_pair(data):
    X, y = [], []
    
    for note in data:
        score = meta[meta.kernel_id == note["kernel_id"]].kaggle_score.iloc[0]
        
        X.append(np.concatenate([
            note["encoded_sequence"], transform_target(note["target"]), [len(note["target"])]
        ]))

        y.append(sigmoid(score))
        
    return np.array(X), np.array(y)

X_train, y_train = generate_data_pair(train_data)
X_test, y_test = generate_data_pair(test_data) 

def test(model, params):
    pipe = Pipeline([
        ("scaler", StandardScaler()),
        ("model", model)
    ])
    
    gs = GridSearchCV(pipe, params, scoring = r2_scorer, verbose = 3, n_jobs = 4)

    gs.fit(X_train, y_train)
    
    best = gs.best_estimator_
    
    print("Best params:", gs.best_params_)
    print("R^2:", best.score(X_test, y_test))
    print("MSE:", MSE(best.predict(X_test), y_test))
    print("MAE:", MAE(best.predict(X_test), y_test))
    return gs

models = dict()

# %%
from sklearn.linear_model import Ridge

params = {
    "model__alpha": [0.1, 1.0, 10.0, 100.0, 1000.0]
}

models["Ridge"] = test(Ridge(), params)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# Best params: {'model__alpha': 100.0}
# R^2: 0.7645602780282413
# MSE: 0.014466908588980613
# MAE: 0.06234268360718438

# %%
from sklearn.linear_model import ElasticNet

params = {
    "model__alpha": [0.001, 0.01, 0.1],
    "model__l1_ratio": [0.1, 0.5, 0.9],
}

models["ElasticNet"] = test(ElasticNet(random_state = 14, max_iter = 3000), params)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.115e+00, tolerance: 7.996e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.036e+01, tolerance: 8.204e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.253e+01, tolerance: 7.821e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.682e+00, tolerance: 8.104e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.005e+01, tolerance: 8.064e-02
#   model = cd_fast.enet_coordinate_descent(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.232e-02, tolerance: 8.204e-02
#   model = cd_fast.enet_coordinate_descent(
# Best params: {'model__alpha': 0.001, 'model__l1_ratio': 0.1}
# R^2: 0.7624323090637526
# MSE: 0.014597664487907213
# MAE: 0.06264463800733885
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.295e+01, tolerance: 1.005e-01
#   model = cd_fast.enet_coordinate_descent(

# %%
from sklearn.ensemble import GradientBoostingRegressor

params = {
    "model__max_depth": [4, 6, 8],
    "model__n_estimators": [50, 100, 150]
}

models["GradientBoostingRegressor"] = test(GradientBoostingRegressor(random_state = 14), params)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END ..................model__alpha=0.1;, score=0.780 total time=   0.7s
# [CV 2/5] END ..................model__alpha=1.0;, score=0.767 total time=   0.6s
# [CV 4/5] END ..................model__alpha=1.0;, score=0.768 total time=   0.5s
# [CV 3/5] END .................model__alpha=10.0;, score=0.785 total time=   0.5s
# [CV 2/5] END ................model__alpha=100.0;, score=0.777 total time=   0.6s
# [CV 1/5] END ...............model__alpha=1000.0;, score=0.766 total time=   0.5s
# [CV 5/5] END ...............model__alpha=1000.0;, score=0.751 total time=   0.5s
# [CV 4/5] END model__alpha=0.001, model__l1_ratio=0.1;, score=0.763 total time=  34.0s
# [CV 5/5] END model__alpha=0.001, model__l1_ratio=0.1;, score=0.774 total time=  40.6s
# [CV 1/5] END model__alpha=0.001, model__l1_ratio=0.9;, score=0.767 total time=  30.0s
# [CV 3/5] END model__alpha=0.001, model__l1_ratio=0.9;, score=0.759 total time=  22.7s
# [CV 3/5] END model__alpha=0.01, model__l1_ratio=0.1;, score=0.751 total time=  25.1s
# [CV 2/5] END model__alpha=0.01, model__l1_ratio=0.5;, score=0.626 total time=   2.7s
# [CV 5/5] END model__alpha=0.01, model__l1_ratio=0.5;, score=0.627 total time=   2.5s
# [CV 5/5] END model__alpha=0.01, model__l1_ratio=0.9;, score=0.547 total time=   1.4s
# [CV 4/5] END model__alpha=0.1, model__l1_ratio=0.1;, score=0.493 total time=   1.1s
# [CV 2/5] END model__alpha=0.1, model__l1_ratio=0.5;, score=0.142 total time=   0.7s
# [CV 4/5] END model__alpha=0.1, model__l1_ratio=0.5;, score=0.145 total time=   0.7s
# [CV 2/5] END model__alpha=0.1, model__l1_ratio=0.9;, score=-0.000 total time=   0.6s
# [CV 5/5] END model__alpha=0.1, model__l1_ratio=0.9;, score=-0.001 total time=   0.6s
# [CV 3/5] END model__max_depth=4, model__n_estimators=50;, score=0.774 total time=  52.7s
# [CV 2/5] END model__max_depth=4, model__n_estimators=100;, score=0.799 total time= 1.7min
# [CV 1/5] END model__max_depth=4, model__n_estimators=150;, score=0.818 total time= 2.6min
# [CV 5/5] END model__max_depth=4, model__n_estimators=150;, score=0.805 total time= 2.7min
# [CV 2/5] END model__max_depth=6, model__n_estimators=100;, score=0.810 total time= 2.6min
# [CV 1/5] END model__max_depth=6, model__n_estimators=150;, score=0.826 total time= 3.9min
# [CV 5/5] END model__max_depth=6, model__n_estimators=150;, score=0.811 total time= 3.9min
# [CV 3/5] END model__max_depth=8, model__n_estimators=100;, score=0.810 total time= 3.4min
# [CV 2/5] END model__max_depth=8, model__n_estimators=150;, score=0.817 total time= 5.2min
# [CV 2/5] END ..................model__alpha=0.1;, score=0.764 total time=   0.7s
# [CV 1/5] END ..................model__alpha=1.0;, score=0.780 total time=   0.7s
# [CV 5/5] END ..................model__alpha=1.0;, score=0.755 total time=   0.6s
# [CV 4/5] END .................model__alpha=10.0;, score=0.769 total time=   0.6s
# [CV 3/5] END ................model__alpha=100.0;, score=0.787 total time=   0.6s
# [CV 3/5] END ...............model__alpha=1000.0;, score=0.757 total time=   0.6s
# [CV 2/5] END model__alpha=0.001, model__l1_ratio=0.1;, score=0.775 total time=  34.3s
# [CV 1/5] END model__alpha=0.001, model__l1_ratio=0.5;, score=0.778 total time=  38.7s
# [CV 4/5] END model__alpha=0.001, model__l1_ratio=0.5;, score=0.742 total time=  32.1s
# [CV 4/5] END model__alpha=0.001, model__l1_ratio=0.9;, score=0.725 total time=  20.2s
# [CV 2/5] END model__alpha=0.01, model__l1_ratio=0.1;, score=0.742 total time=  27.5s
# [CV 3/5] END model__alpha=0.01, model__l1_ratio=0.5;, score=0.633 total time=   2.4s
# [CV 1/5] END model__alpha=0.01, model__l1_ratio=0.9;, score=0.566 total time=   1.3s
# [CV 3/5] END model__alpha=0.01, model__l1_ratio=0.9;, score=0.544 total time=   1.2s
# [CV 1/5] END model__alpha=0.1, model__l1_ratio=0.1;, score=0.531 total time=   1.1s
# [CV 3/5] END model__alpha=0.1, model__l1_ratio=0.1;, score=0.509 total time=   1.1s
# [CV 1/5] END model__alpha=0.1, model__l1_ratio=0.5;, score=0.144 total time=   0.7s
# [CV 3/5] END model__alpha=0.1, model__l1_ratio=0.5;, score=0.142 total time=   0.7s
# [CV 1/5] END model__alpha=0.1, model__l1_ratio=0.9;, score=-0.001 total time=   0.7s
# [CV 4/5] END model__alpha=0.1, model__l1_ratio=0.9;, score=-0.000 total time=   0.6s
# [CV 2/5] END model__max_depth=4, model__n_estimators=50;, score=0.775 total time=  52.9s
# [CV 3/5] END model__max_depth=4, model__n_estimators=100;, score=0.796 total time= 1.8min
# [CV 2/5] END model__max_depth=4, model__n_estimators=150;, score=0.806 total time= 2.7min
# [CV 1/5] END model__max_depth=6, model__n_estimators=50;, score=0.815 total time= 1.2min
# [CV 3/5] END model__max_depth=6, model__n_estimators=50;, score=0.802 total time= 1.2min
# [CV 1/5] END model__max_depth=6, model__n_estimators=100;, score=0.824 total time= 2.6min
# [CV 5/5] END model__max_depth=6, model__n_estimators=100;, score=0.809 total time= 2.6min
# [CV 4/5] END model__max_depth=6, model__n_estimators=150;, score=0.780 total time= 3.9min
# [CV 5/5] END model__max_depth=8, model__n_estimators=50;, score=0.807 total time= 1.6min
# [CV 4/5] END model__max_depth=8, model__n_estimators=100;, score=0.784 total time= 3.4min
# [CV 3/5] END model__max_depth=8, model__n_estimators=150;, score=0.809 total time= 5.2min
# [CV 3/5] END ..................model__alpha=0.1;, score=0.776 total time=   0.7s
# [CV 5/5] END ..................model__alpha=0.1;, score=0.753 total time=   0.7s
# [CV 1/5] END .................model__alpha=10.0;, score=0.785 total time=   0.6s
# [CV 5/5] END .................model__alpha=10.0;, score=0.765 total time=   0.6s
# [CV 4/5] END ................model__alpha=100.0;, score=0.763 total time=   0.6s
# [CV 2/5] END ...............model__alpha=1000.0;, score=0.754 total time=   0.6s
# [CV 1/5] END model__alpha=0.001, model__l1_ratio=0.1;, score=0.787 total time=  34.6s
# [CV 2/5] END model__alpha=0.001, model__l1_ratio=0.5;, score=0.764 total time=  46.7s
# [CV 2/5] END model__alpha=0.001, model__l1_ratio=0.9;, score=0.750 total time=  24.1s
# [CV 5/5] END model__alpha=0.001, model__l1_ratio=0.9;, score=0.744 total time=  22.9s
# [CV 4/5] END model__alpha=0.01, model__l1_ratio=0.1;, score=0.717 total time=  23.2s
# [CV 1/5] END model__alpha=0.01, model__l1_ratio=0.5;, score=0.651 total time=   2.2s
# [CV 4/5] END model__alpha=0.01, model__l1_ratio=0.5;, score=0.605 total time=   2.1s
# [CV 2/5] END model__alpha=0.01, model__l1_ratio=0.9;, score=0.537 total time=   1.4s
# [CV 4/5] END model__alpha=0.01, model__l1_ratio=0.9;, score=0.526 total time=   1.4s
# [CV 2/5] END model__alpha=0.1, model__l1_ratio=0.1;, score=0.503 total time=   1.2s
# [CV 5/5] END model__alpha=0.1, model__l1_ratio=0.1;, score=0.513 total time=   1.2s
# [CV 5/5] END model__alpha=0.1, model__l1_ratio=0.5;, score=0.148 total time=   0.7s
# [CV 3/5] END model__alpha=0.1, model__l1_ratio=0.9;, score=-0.004 total time=   0.7s
# [CV 1/5] END model__max_depth=4, model__n_estimators=50;, score=0.792 total time=  52.2s
# [CV 1/5] END model__max_depth=4, model__n_estimators=100;, score=0.810 total time= 1.7min
# [CV 5/5] END model__max_depth=4, model__n_estimators=100;, score=0.798 total time= 1.7min
# [CV 4/5] END model__max_depth=4, model__n_estimators=150;, score=0.773 total time= 2.6min
# [CV 4/5] END model__max_depth=6, model__n_estimators=50;, score=0.773 total time= 1.2min
# [CV 3/5] END model__max_depth=6, model__n_estimators=100;, score=0.809 total time= 2.6min
# [CV 2/5] END model__max_depth=6, model__n_estimators=150;, score=0.813 total time= 3.9min
# [CV 1/5] END model__max_depth=8, model__n_estimators=50;, score=0.821 total time= 1.6min
# [CV 3/5] END model__max_depth=8, model__n_estimators=50;, score=0.809 total time= 1.6min
# [CV 1/5] END model__max_depth=8, model__n_estimators=100;, score=0.825 total time= 3.4min
# [CV 5/5] END model__max_depth=8, model__n_estimators=100;, score=0.809 total time= 3.4min
# [CV 4/5] END model__max_depth=8, model__n_estimators=150;, score=0.786 total time= 4.8min
# [CV 4/5] END ..................model__alpha=0.1;, score=0.767 total time=   0.7s
# [CV 3/5] END ..................model__alpha=1.0;, score=0.779 total time=   0.7s
# [CV 2/5] END .................model__alpha=10.0;, score=0.774 total time=   0.6s
# [CV 1/5] END ................model__alpha=100.0;, score=0.786 total time=   0.6s
# [CV 5/5] END ................model__alpha=100.0;, score=0.774 total time=   0.6s
# [CV 4/5] END ...............model__alpha=1000.0;, score=0.733 total time=   0.6s
# [CV 3/5] END model__alpha=0.001, model__l1_ratio=0.1;, score=0.787 total time=  35.2s
# [CV 3/5] END model__alpha=0.001, model__l1_ratio=0.5;, score=0.772 total time=  38.3s
# [CV 5/5] END model__alpha=0.001, model__l1_ratio=0.5;, score=0.759 total time=  43.1s
# [CV 1/5] END model__alpha=0.01, model__l1_ratio=0.1;, score=0.760 total time=  26.1s
# [CV 5/5] END model__alpha=0.01, model__l1_ratio=0.1;, score=0.737 total time=  20.0s
# [CV 4/5] END model__max_depth=4, model__n_estimators=50;, score=0.746 total time=  51.6s
# [CV 5/5] END model__max_depth=4, model__n_estimators=50;, score=0.778 total time=  50.9s
# [CV 4/5] END model__max_depth=4, model__n_estimators=100;, score=0.767 total time= 1.7min
# [CV 3/5] END model__max_depth=4, model__n_estimators=150;, score=0.804 total time= 2.6min
# [CV 2/5] END model__max_depth=6, model__n_estimators=50;, score=0.801 total time= 1.2min
# [CV 5/5] END model__max_depth=6, model__n_estimators=50;, score=0.802 total time= 1.2min
# [CV 4/5] END model__max_depth=6, model__n_estimators=100;, score=0.779 total time= 2.6min
# [CV 3/5] END model__max_depth=6, model__n_estimators=150;, score=0.809 total time= 3.9min
# [CV 2/5] END model__max_depth=8, model__n_estimators=50;, score=0.813 total time= 1.5min
# [CV 4/5] END model__max_depth=8, model__n_estimators=50;, score=0.781 total time= 1.6min
# [CV 2/5] END model__max_depth=8, model__n_estimators=100;, score=0.816 total time= 3.4min
# [CV 1/5] END model__max_depth=8, model__n_estimators=150;, score=0.826 total time= 5.2min
# [CV 5/5] END model__max_depth=8, model__n_estimators=150;, score=0.809 total time= 4.3min
# Best params: {'model__max_depth': 8, 'model__n_estimators': 150}
# R^2: 0.8035986209225289
# MSE: 0.012068145400733716
# MAE: 0.05384242357521649

# %%
from sklearn.ensemble import RandomForestRegressor

params = {
    "model__max_depth": [4, 6, 8, None],
    "model__n_estimators": [50, 100, 150]
}

models["RandomForestRegressor"] = test(RandomForestRegressor(random_state = 14), params)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END model__max_depth=4, model__n_estimators=50;, score=0.542 total time=  34.0s
# [CV 5/5] END model__max_depth=4, model__n_estimators=50;, score=0.512 total time=  33.8s
# [CV 4/5] END model__max_depth=4, model__n_estimators=100;, score=0.498 total time= 1.1min
# [CV 3/5] END model__max_depth=4, model__n_estimators=150;, score=0.535 total time= 1.7min
# [CV 2/5] END model__max_depth=6, model__n_estimators=50;, score=0.598 total time=  50.2s
# [CV 5/5] END model__max_depth=6, model__n_estimators=50;, score=0.607 total time=  49.9s
# [CV 4/5] END model__max_depth=6, model__n_estimators=100;, score=0.593 total time= 1.7min
# [CV 3/5] END model__max_depth=6, model__n_estimators=150;, score=0.637 total time= 2.5min
# [CV 2/5] END model__max_depth=8, model__n_estimators=50;, score=0.670 total time= 1.1min
# [CV 4/5] END model__max_depth=8, model__n_estimators=50;, score=0.670 total time= 1.1min
# [CV 3/5] END model__max_depth=8, model__n_estimators=100;, score=0.704 total time= 2.1min
# [CV 2/5] END model__max_depth=8, model__n_estimators=150;, score=0.671 total time= 3.2min
# [CV 1/5] END model__max_depth=None, model__n_estimators=50;, score=0.815 total time= 2.6min
# [CV 4/5] END model__max_depth=None, model__n_estimators=50;, score=0.782 total time= 2.6min
# [CV 3/5] END model__max_depth=None, model__n_estimators=100;, score=0.816 total time= 5.3min
# [CV 2/5] END model__max_depth=None, model__n_estimators=150;, score=0.814 total time= 7.9min
# [CV 3/5] END model__max_depth=4, model__n_estimators=50;, score=0.532 total time=  34.4s
# [CV 2/5] END model__max_depth=4, model__n_estimators=100;, score=0.499 total time= 1.1min
# [CV 1/5] END model__max_depth=4, model__n_estimators=150;, score=0.542 total time= 1.7min
# [CV 1/5] END model__max_depth=6, model__n_estimators=50;, score=0.624 total time=  50.3s
# [CV 3/5] END model__max_depth=6, model__n_estimators=50;, score=0.638 total time=  50.8s
# [CV 1/5] END model__max_depth=6, model__n_estimators=100;, score=0.625 total time= 1.7min
# [CV 5/5] END model__max_depth=6, model__n_estimators=100;, score=0.609 total time= 1.7min
# [CV 4/5] END model__max_depth=6, model__n_estimators=150;, score=0.592 total time= 2.5min
# [CV 5/5] END model__max_depth=8, model__n_estimators=50;, score=0.679 total time= 1.1min
# [CV 4/5] END model__max_depth=8, model__n_estimators=100;, score=0.669 total time= 2.1min
# [CV 3/5] END model__max_depth=8, model__n_estimators=150;, score=0.706 total time= 3.2min
# [CV 2/5] END model__max_depth=None, model__n_estimators=50;, score=0.813 total time= 2.7min
# [CV 5/5] END model__max_depth=None, model__n_estimators=50;, score=0.810 total time= 2.7min
# [CV 4/5] END model__max_depth=None, model__n_estimators=100;, score=0.783 total time= 5.2min
# [CV 3/5] END model__max_depth=None, model__n_estimators=150;, score=0.817 total time= 7.8min
# [CV 4/5] END model__max_depth=4, model__n_estimators=50;, score=0.499 total time=  34.5s
# [CV 3/5] END model__max_depth=4, model__n_estimators=100;, score=0.534 total time= 1.1min
# [CV 2/5] END model__max_depth=4, model__n_estimators=150;, score=0.501 total time= 1.7min
# [CV 5/5] END model__max_depth=4, model__n_estimators=150;, score=0.513 total time= 1.7min
# [CV 2/5] END model__max_depth=6, model__n_estimators=100;, score=0.597 total time= 1.7min
# [CV 1/5] END model__max_depth=6, model__n_estimators=150;, score=0.627 total time= 2.5min
# [CV 5/5] END model__max_depth=6, model__n_estimators=150;, score=0.610 total time= 2.5min
# [CV 2/5] END model__max_depth=8, model__n_estimators=100;, score=0.670 total time= 2.1min
# [CV 1/5] END model__max_depth=8, model__n_estimators=150;, score=0.694 total time= 3.2min
# [CV 5/5] END model__max_depth=8, model__n_estimators=150;, score=0.679 total time= 3.2min
# [CV 1/5] END model__max_depth=None, model__n_estimators=100;, score=0.815 total time= 5.3min
# [CV 5/5] END model__max_depth=None, model__n_estimators=100;, score=0.811 total time= 5.3min
# [CV 4/5] END model__max_depth=None, model__n_estimators=150;, score=0.784 total time= 7.3min
# [CV 2/5] END model__max_depth=4, model__n_estimators=50;, score=0.499 total time=  34.2s
# [CV 1/5] END model__max_depth=4, model__n_estimators=100;, score=0.542 total time= 1.1min
# [CV 5/5] END model__max_depth=4, model__n_estimators=100;, score=0.512 total time= 1.1min
# [CV 4/5] END model__max_depth=4, model__n_estimators=150;, score=0.500 total time= 1.7min
# [CV 4/5] END model__max_depth=6, model__n_estimators=50;, score=0.595 total time=  49.8s
# [CV 3/5] END model__max_depth=6, model__n_estimators=100;, score=0.637 total time= 1.7min
# [CV 2/5] END model__max_depth=6, model__n_estimators=150;, score=0.598 total time= 2.5min
# [CV 1/5] END model__max_depth=8, model__n_estimators=50;, score=0.691 total time= 1.1min
# [CV 3/5] END model__max_depth=8, model__n_estimators=50;, score=0.704 total time= 1.1min
# [CV 1/5] END model__max_depth=8, model__n_estimators=100;, score=0.691 total time= 2.1min
# [CV 5/5] END model__max_depth=8, model__n_estimators=100;, score=0.679 total time= 2.1min
# [CV 4/5] END model__max_depth=8, model__n_estimators=150;, score=0.668 total time= 3.2min
# [CV 3/5] END model__max_depth=None, model__n_estimators=50;, score=0.816 total time= 2.6min
# [CV 2/5] END model__max_depth=None, model__n_estimators=100;, score=0.814 total time= 5.4min
# [CV 1/5] END model__max_depth=None, model__n_estimators=150;, score=0.817 total time= 7.8min
# [CV 5/5] END model__max_depth=None, model__n_estimators=150;, score=0.811 total time= 6.7min
# Best params: {'model__max_depth': None, 'model__n_estimators': 150}
# R^2: 0.810490834471198
# MSE: 0.011644644121725709
# MAE: 0.04965098383318193

# %%
from sklearn.svm import LinearSVR

params = {
    "model__loss": ("epsilon_insensitive", "squared_epsilon_insensitive"),
    "model__C": [0.01, 0.1, 1.0, 10.0, 100.0]
}

models["LinearSVR"] = test(LinearSVR(random_state = 14, max_iter = 5000), params)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /home/razin-arslan/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Best params: {'model__C': 0.01, 'model__loss': 'squared_epsilon_insensitive'}
# R^2: 0.7659806957404518
# MSE: 0.014379629123015294
# MAE: 0.061805803990027386
# [CV 4/5] END model__C=0.01, model__loss=epsilon_insensitive;, score=0.745 total time= 1.5min
# [CV 3/5] END model__C=0.01, model__loss=squared_epsilon_insensitive;, score=0.788 total time=   9.3s
# [CV 5/5] END model__C=0.01, model__loss=squared_epsilon_insensitive;, score=0.773 total time=   9.7s
# [CV 3/5] END model__C=0.1, model__loss=epsilon_insensitive;, score=0.749 total time= 2.7min
# [CV 1/5] END model__C=0.1, model__loss=squared_epsilon_insensitive;, score=0.783 total time= 1.6min
# [CV 4/5] END model__C=0.1, model__loss=squared_epsilon_insensitive;, score=0.769 total time= 1.4min
# [CV 3/5] END model__C=1.0, model__loss=epsilon_insensitive;, score=0.699 total time= 3.1min
# [CV 2/5] END model__C=1.0, model__loss=squared_epsilon_insensitive;, score=0.764 total time= 3.0min
# [CV 1/5] END model__C=10.0, model__loss=epsilon_insensitive;, score=0.590 total time= 2.7min
# [CV 5/5] END model__C=10.0, model__loss=epsilon_insensitive;, score=0.404 total time= 2.7min
# [CV 4/5] END model__C=10.0, model__loss=squared_epsilon_insensitive;, score=0.640 total time= 2.7min
# [CV 3/5] END model__C=100.0, model__loss=epsilon_insensitive;, score=0.145 total time= 2.7min
# [CV 2/5] END model__C=100.0, model__loss=squared_epsilon_insensitive;, score=0.411 total time= 2.6min
# [CV 2/5] END model__C=0.01, model__loss=epsilon_insensitive;, score=0.732 total time= 1.5min
# [CV 1/5] END model__C=0.01, model__loss=squared_epsilon_insensitive;, score=0.788 total time=   9.9s
# [CV 4/5] END model__C=0.01, model__loss=squared_epsilon_insensitive;, score=0.766 total time=   9.2s
# [CV 2/5] END model__C=0.1, model__loss=epsilon_insensitive;, score=0.713 total time= 2.7min
# [CV 2/5] END model__C=0.1, model__loss=squared_epsilon_insensitive;, score=0.771 total time= 1.7min
# [CV 5/5] END model__C=0.1, model__loss=squared_epsilon_insensitive;, score=0.761 total time= 1.5min
# [CV 4/5] END model__C=1.0, model__loss=epsilon_insensitive;, score=0.732 total time= 3.1min
# [CV 3/5] END model__C=1.0, model__loss=squared_epsilon_insensitive;, score=0.765 total time= 3.0min
# [CV 2/5] END model__C=10.0, model__loss=epsilon_insensitive;, score=0.392 total time= 2.7min
# [CV 1/5] END model__C=10.0, model__loss=squared_epsilon_insensitive;, score=0.661 total time= 2.7min
# [CV 5/5] END model__C=10.0, model__loss=squared_epsilon_insensitive;, score=0.561 total time= 2.6min
# [CV 4/5] END model__C=100.0, model__loss=epsilon_insensitive;, score=0.543 total time= 2.7min
# [CV 3/5] END model__C=100.0, model__loss=squared_epsilon_insensitive;, score=0.173 total time= 2.6min
# [CV 1/5] END model__C=0.01, model__loss=epsilon_insensitive;, score=0.762 total time= 1.5min
# [CV 2/5] END model__C=0.01, model__loss=squared_epsilon_insensitive;, score=0.778 total time=   9.8s
# [CV 1/5] END model__C=0.1, model__loss=epsilon_insensitive;, score=0.754 total time= 2.7min
# [CV 5/5] END model__C=0.1, model__loss=epsilon_insensitive;, score=0.727 total time= 2.4min
# [CV 1/5] END model__C=1.0, model__loss=epsilon_insensitive;, score=0.734 total time= 2.8min
# [CV 5/5] END model__C=1.0, model__loss=epsilon_insensitive;, score=0.706 total time= 3.3min
# [CV 4/5] END model__C=1.0, model__loss=squared_epsilon_insensitive;, score=0.764 total time= 2.7min
# [CV 3/5] END model__C=10.0, model__loss=epsilon_insensitive;, score=0.145 total time= 2.7min
# [CV 2/5] END model__C=10.0, model__loss=squared_epsilon_insensitive;, score=0.537 total time= 2.6min
# [CV 1/5] END model__C=100.0, model__loss=epsilon_insensitive;, score=0.590 total time= 2.7min
# [CV 5/5] END model__C=100.0, model__loss=epsilon_insensitive;, score=0.404 total time= 2.6min
# [CV 4/5] END model__C=100.0, model__loss=squared_epsilon_insensitive;, score=0.556 total time= 2.2min
# [CV 3/5] END model__C=0.01, model__loss=epsilon_insensitive;, score=0.758 total time= 1.5min
# [CV 5/5] END model__C=0.01, model__loss=epsilon_insensitive;, score=0.746 total time= 1.5min
# [CV 4/5] END model__C=0.1, model__loss=epsilon_insensitive;, score=0.744 total time= 2.8min
# [CV 3/5] END model__C=0.1, model__loss=squared_epsilon_insensitive;, score=0.783 total time= 1.5min
# [CV 2/5] END model__C=1.0, model__loss=epsilon_insensitive;, score=0.709 total time= 2.9min
# [CV 1/5] END model__C=1.0, model__loss=squared_epsilon_insensitive;, score=0.771 total time= 3.2min
# [CV 5/5] END model__C=1.0, model__loss=squared_epsilon_insensitive;, score=0.751 total time= 2.7min
# [CV 4/5] END model__C=10.0, model__loss=epsilon_insensitive;, score=0.543 total time= 2.7min
# [CV 3/5] END model__C=10.0, model__loss=squared_epsilon_insensitive;, score=0.372 total time= 2.6min
# [CV 2/5] END model__C=100.0, model__loss=epsilon_insensitive;, score=0.392 total time= 2.7min
# [CV 1/5] END model__C=100.0, model__loss=squared_epsilon_insensitive;, score=0.599 total time= 2.6min
# [CV 5/5] END model__C=100.0, model__loss=squared_epsilon_insensitive;, score=0.425 total time= 2.1min

# %%
df = pd.DataFrame(models["Ridge"].cv_results_)
df.to_csv("Ridge.csv")
df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.652214      0.020995         0.029574        0.003468
# 1       0.595645      0.062688         0.025659        0.001189
# 2       0.575381      0.038133         0.024686        0.001730
# 3       0.578961      0.018919         0.024993        0.001552
# 4       0.553888      0.048630         0.021308        0.008039
#
#   param_model__alpha                    params  split0_test_score  \
# 0                0.1     {'model__alpha': 0.1}           0.780254
# 1                1.0     {'model__alpha': 1.0}           0.780223
# 2               10.0    {'model__alpha': 10.0}           0.785315
# 3              100.0   {'model__alpha': 100.0}           0.786389
# 4             1000.0  {'model__alpha': 1000.0}           0.766342
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.764380           0.776462           0.767002           0.753070
# 1           0.767413           0.778555           0.767700           0.755455
# 2           0.773640           0.785186           0.769044           0.764571
# 3           0.777181           0.786678           0.762779           0.773515
# 4           0.753737           0.756758           0.733209           0.750895
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.768234        0.009576                4
# 1         0.769869        0.008957                3
# 2         0.775551        0.008423                2
# 3         0.777309        0.008897                1
# 4         0.752188        0.010821                5

# %%
df = pd.DataFrame(models["ElasticNet"].cv_results_)
df.to_csv("ElasticNet.csv")
df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      35.716229      2.462536         0.028339        0.003555
# 1      39.755957      4.929681         0.034823        0.004319
# 2      23.930580      3.253267         0.036122        0.004659
# 3      24.365487      2.581859         0.030674        0.010755
# 4       2.365579      0.203261         0.032324        0.004178
# 5       1.301325      0.048831         0.035071        0.003406
# 6       1.099869      0.071947         0.033259        0.005486
# 7       0.666797      0.015189         0.032061        0.002425
# 8       0.614359      0.041245         0.028622        0.003744
#
#   param_model__alpha param_model__l1_ratio  \
# 0              0.001                   0.1
# 1              0.001                   0.5
# 2              0.001                   0.9
# 3               0.01                   0.1
# 4               0.01                   0.5
# 5               0.01                   0.9
# 6                0.1                   0.1
# 7                0.1                   0.5
# 8                0.1                   0.9
#
#                                             params  split0_test_score  \
# 0  {'model__alpha': 0.001, 'model__l1_ratio': 0.1}           0.786949
# 1  {'model__alpha': 0.001, 'model__l1_ratio': 0.5}           0.777588
# 2  {'model__alpha': 0.001, 'model__l1_ratio': 0.9}           0.767092
# 3   {'model__alpha': 0.01, 'model__l1_ratio': 0.1}           0.759515
# 4   {'model__alpha': 0.01, 'model__l1_ratio': 0.5}           0.651266
# 5   {'model__alpha': 0.01, 'model__l1_ratio': 0.9}           0.566047
# 6    {'model__alpha': 0.1, 'model__l1_ratio': 0.1}           0.531104
# 7    {'model__alpha': 0.1, 'model__l1_ratio': 0.5}           0.143762
# 8    {'model__alpha': 0.1, 'model__l1_ratio': 0.9}          -0.000917
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.775127           0.786845           0.762821           0.773938
# 1           0.763834           0.771933           0.742391           0.759348
# 2           0.749825           0.758900           0.724965           0.744107
# 3           0.742461           0.750817           0.716540           0.736601
# 4           0.625773           0.633303           0.605142           0.626992
# 5           0.536870           0.543530           0.525642           0.546595
# 6           0.502823           0.508880           0.493334           0.513138
# 7           0.141860           0.142403           0.145188           0.148243
# 8          -0.000002          -0.003950          -0.000018          -0.000739
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.777136        0.009053                1
# 1         0.763019        0.012095                2
# 2         0.748978        0.014336                3
# 3         0.741187        0.014552                4
# 4         0.628495        0.014810                5
# 5         0.543737        0.013270                6
# 6         0.509856        0.012535                7
# 7         0.144291        0.002288                8
# 8        -0.001125        0.001460                9

# %%
df = pd.DataFrame(models["LinearSVR"].cv_results_)
df.to_csv("LinearSVR.csv")
df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      90.259837      1.320352         0.057826        0.021372
# 1       9.569485      0.284682         0.016162        0.000988
# 2     159.295112      6.707989         0.019537        0.003786
# 3      91.483284      5.116170         0.016444        0.001434
# 4     182.356764      8.644955         0.020906        0.003263
# 5     175.827229     11.167339         0.016459        0.001458
# 6     161.023362      1.752178         0.015880        0.001246
# 7     158.728495      0.860527         0.016440        0.001372
# 8     160.284822      1.114932         0.016532        0.001588
# 9     145.407548     13.928060         0.013573        0.002072
#
#   param_model__C            param_model__loss  \
# 0           0.01          epsilon_insensitive
# 1           0.01  squared_epsilon_insensitive
# 2            0.1          epsilon_insensitive
# 3            0.1  squared_epsilon_insensitive
# 4            1.0          epsilon_insensitive
# 5            1.0  squared_epsilon_insensitive
# 6           10.0          epsilon_insensitive
# 7           10.0  squared_epsilon_insensitive
# 8          100.0          epsilon_insensitive
# 9          100.0  squared_epsilon_insensitive
#
#                                               params  split0_test_score  \
# 0  {'model__C': 0.01, 'model__loss': 'epsilon_ins...           0.761934
# 1  {'model__C': 0.01, 'model__loss': 'squared_eps...           0.787689
# 2  {'model__C': 0.1, 'model__loss': 'epsilon_inse...           0.754498
# 3  {'model__C': 0.1, 'model__loss': 'squared_epsi...           0.783267
# 4  {'model__C': 1.0, 'model__loss': 'epsilon_inse...           0.734493
# 5  {'model__C': 1.0, 'model__loss': 'squared_epsi...           0.770812
# 6  {'model__C': 10.0, 'model__loss': 'epsilon_ins...           0.589766
# 7  {'model__C': 10.0, 'model__loss': 'squared_eps...           0.661289
# 8  {'model__C': 100.0, 'model__loss': 'epsilon_in...           0.589766
# 9  {'model__C': 100.0, 'model__loss': 'squared_ep...           0.598931
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.732325           0.757505           0.744981           0.745794
# 1           0.777539           0.787956           0.766106           0.772761
# 2           0.712556           0.748722           0.743867           0.726648
# 3           0.771273           0.782579           0.768802           0.760735
# 4           0.709500           0.698961           0.732278           0.705868
# 5           0.763647           0.765426           0.764314           0.751483
# 6           0.392490           0.145206           0.542638           0.403936
# 7           0.537052           0.371887           0.640227           0.560688
# 8           0.392490           0.145206           0.542638           0.403936
# 9           0.410548           0.173150           0.555540           0.424509
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.748508        0.010420                4
# 1         0.778410        0.008501                1
# 2         0.737258        0.015460                5
# 3         0.773331        0.008575                2
# 4         0.716220        0.014436                6
# 5         0.763136        0.006350                3
# 6         0.414807        0.155082                9
# 7         0.554228        0.102414                7
# 8         0.414807        0.155082                9
# 9         0.432536        0.148759                8

# %%
df = pd.DataFrame(models["GradientBoostingRegressor"].cv_results_)
df.to_csv("GradientBoostingRegressor.csv")
df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      52.027580      0.748877         0.027726        0.001582
# 1     103.970696      0.725330         0.032390        0.000410
# 2     158.188339      0.820744         0.036558        0.000372
# 3      73.431068      0.708227         0.030543        0.000637
# 4     154.791722      0.910157         0.036936        0.000568
# 5     236.340085      0.361171         0.042633        0.001349
# 6      93.786086      0.767140         0.032558        0.000955
# 7     202.546509      0.697256         0.041576        0.000632
# 8     295.853334     19.945219         0.041941        0.006580
#
#   param_model__max_depth param_model__n_estimators  \
# 0                      4                        50
# 1                      4                       100
# 2                      4                       150
# 3                      6                        50
# 4                      6                       100
# 5                      6                       150
# 6                      8                        50
# 7                      8                       100
# 8                      8                       150
#
#                                               params  split0_test_score  \
# 0  {'model__max_depth': 4, 'model__n_estimators':...           0.792115
# 1  {'model__max_depth': 4, 'model__n_estimators':...           0.810389
# 2  {'model__max_depth': 4, 'model__n_estimators':...           0.817855
# 3  {'model__max_depth': 6, 'model__n_estimators':...           0.814558
# 4  {'model__max_depth': 6, 'model__n_estimators':...           0.823518
# 5  {'model__max_depth': 6, 'model__n_estimators':...           0.825907
# 6  {'model__max_depth': 8, 'model__n_estimators':...           0.821300
# 7  {'model__max_depth': 8, 'model__n_estimators':...           0.825275
# 8  {'model__max_depth': 8, 'model__n_estimators':...           0.826283
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.774761           0.774254           0.745993           0.778461
# 1           0.798730           0.796236           0.766840           0.798330
# 2           0.806258           0.804243           0.772940           0.805043
# 3           0.801478           0.802490           0.773001           0.801524
# 4           0.809647           0.808897           0.779351           0.808739
# 5           0.812607           0.809128           0.780032           0.811237
# 6           0.812602           0.808815           0.781020           0.806524
# 7           0.815836           0.809512           0.784025           0.809474
# 8           0.816615           0.808535           0.785856           0.809489
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.773117        0.015028                9
# 1         0.794105        0.014508                8
# 2         0.801268        0.015004                6
# 3         0.798610        0.013725                7
# 4         0.806030        0.014465                5
# 5         0.807782        0.015071                3
# 6         0.806052        0.013489                4
# 7         0.808824        0.013680                2
# 8         0.809356        0.013358                1

# %%
df = pd.DataFrame(models["RandomForestRegressor"].cv_results_)
df.to_csv("RandomForestRegressor.csv")
df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       34.153160      0.252268         0.027616        0.002270
# 1       67.942859      0.287103         0.033145        0.002024
# 2      102.135229      0.402760         0.036365        0.001387
# 3       50.157058      0.336967         0.026386        0.001088
# 4      100.250093      0.489691         0.034009        0.000638
# 5      149.471696      0.587328         0.042181        0.000372
# 6       64.125926      0.237221         0.028869        0.000455
# 7      128.197812      0.306128         0.041595        0.000748
# 8      192.188969      0.411613         0.052409        0.002175
# 9      157.689254      2.339161         0.085481        0.002341
# 10     318.126973      2.863893         0.155607        0.002863
# 11     450.206207     28.114366         0.199561        0.026250
#
#    param_model__max_depth param_model__n_estimators  \
# 0                       4                        50
# 1                       4                       100
# 2                       4                       150
# 3                       6                        50
# 4                       6                       100
# 5                       6                       150
# 6                       8                        50
# 7                       8                       100
# 8                       8                       150
# 9                    None                        50
# 10                   None                       100
# 11                   None                       150
#
#                                                params  split0_test_score  \
# 0   {'model__max_depth': 4, 'model__n_estimators':...           0.541868
# 1   {'model__max_depth': 4, 'model__n_estimators':...           0.541919
# 2   {'model__max_depth': 4, 'model__n_estimators':...           0.541591
# 3   {'model__max_depth': 6, 'model__n_estimators':...           0.624369
# 4   {'model__max_depth': 6, 'model__n_estimators':...           0.624894
# 5   {'model__max_depth': 6, 'model__n_estimators':...           0.626845
# 6   {'model__max_depth': 8, 'model__n_estimators':...           0.690941
# 7   {'model__max_depth': 8, 'model__n_estimators':...           0.691143
# 8   {'model__max_depth': 8, 'model__n_estimators':...           0.693599
# 9   {'model__max_depth': None, 'model__n_estimator...           0.814747
# 10  {'model__max_depth': None, 'model__n_estimator...           0.815079
# 11  {'model__max_depth': None, 'model__n_estimator...           0.816533
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.498536           0.532178           0.498986
# 1            0.499342           0.534423           0.498167
# 2            0.500656           0.534694           0.500264
# 3            0.598066           0.638092           0.595173
# 4            0.597378           0.636771           0.593201
# 5            0.598343           0.637497           0.592197
# 6            0.669760           0.704055           0.670033
# 7            0.670439           0.704133           0.668502
# 8            0.671084           0.705705           0.668045
# 9            0.813250           0.815844           0.781531
# 10           0.813888           0.816465           0.783305
# 11           0.814286           0.817416           0.784439
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.511606         0.516635        0.017565               12
# 1            0.511671         0.517105        0.017996               11
# 2            0.513089         0.518059        0.017174               10
# 3            0.607387         0.612617        0.016312                8
# 4            0.609436         0.612336        0.016450                9
# 5            0.609761         0.612929        0.017028                7
# 6            0.679074         0.682773        0.013153                5
# 7            0.679289         0.682701        0.013373                6
# 8            0.679477         0.683582        0.014172                4
# 9            0.809861         0.807047        0.012916                3
# 10           0.811321         0.808012        0.012468                2
# 11           0.811298         0.808794        0.012360                1
